# %%
#!mlflow models serve -m models:/trained_model/latest --env-manager=local --port 5001 --no-conda
# Out:
# 'mlflow' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
import requests

row = [
    1,	33.8183,	-118.3868,	8,	2,	0,	25
]

resp = requests.post(
    "http://localhost:5001/invocations",
    headers={"Content-Type": "application/json"},
    json={
        "inputs": [row],
    }
)
resp.status_code
resp.json()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ction.py:198 in _new_conn                                                                        │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\util\ │
# │ connection.py:85 in create_connection                                                            │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\util\ │
# │ connection.py:73 in create_connection                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou
# ativamente
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ctionpool.py:787 in urlopen                                                                      │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ctionpool.py:493 in _make_request                                                                │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ction.py:445 in request                                                                          │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\http\client.py:1298 in      │
# │ endheaders                                                                                       │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\http\client.py:1058 in      │
# │ _send_output                                                                                     │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\http\client.py:996 in send  │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ction.py:276 in connect                                                                          │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ction.py:213 in _new_conn                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000251BBF62B10>: Failed to establish a new
# connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\adap │
# │ ters.py:667 in send                                                                              │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\conne │
# │ ctionpool.py:841 in urlopen                                                                      │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\urllib3\util\ │
# │ retry.py:519 in increment                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# MaxRetryError: HTTPConnectionPool(host='localhost', port=5001): Max retries exceeded with url: /invocations (Caused
# by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000251BBF62B10>: Failed to establish a new
# connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4 │   1,  33.8183,    -118.3868,  8,  2,  0,  25                                              │
# │    5 ]                                                                                           │
# │    6                                                                                             │
# │ ❱  7 resp = requests.post(                                                                       │
# │    8 │   "http://localhost:5001/invocations",                                                    │
# │    9 │   headers={"Content-Type": "application/json"},                                           │
# │   10 │   json={                                                                                  │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\api. │
# │ py:115 in post                                                                                   │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\api. │
# │ py:59 in request                                                                                 │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\sess │
# │ ions.py:589 in request                                                                           │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\sess │
# │ ions.py:703 in send                                                                              │
# │                                                                                                  │
# │ c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\requests\adap │
# │ ters.py:700 in send                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ConnectionError: HTTPConnectionPool(host='localhost', port=5001): Max retries exceeded with url: /invocations
# (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000251BBF62B10>: Failed to
# establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou
# ativamente'))
