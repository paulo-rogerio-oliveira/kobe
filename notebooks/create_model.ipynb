# %%
import pandas as pd
import mlflow
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, f1_score
from pycaret.classification import setup, create_model, predict_model, save_model


def Treinamento(
    target: str = "shot_made_flag",
    modelo_saida: str = "modelo_final"
):
    """Treina dois modelos com PyCaret, registra métricas no MLflow e retorna o melhor."""
         
    df_train = catalog.load("base_train")
    df_test = catalog.load("base_test")
    
    # Inicia a run no MLflow
    with mlflow.start_run(run_name="Treinamento"):
        # 1. Setup PyCaret
        exp = setup(
            data=df_train,
            target=target,
            session_id=42,
            log_experiment=False,  # gerencia logs via mlflow diretamente
        )
  
        # 2. Treinamento dos modelos
        lr = create_model("lr")      # Regressão Logística
        dt = create_model("dt")      # Decision Tree
        
        # 3. Avaliação na base de teste
        # Previsões
        pred_lr = predict_model(lr, data=df_test)
        pred_dt = predict_model(dt, data=df_test)

        print(pred_dt)
        # PyCaret adiciona coluna "Label" e "Score"
        y_true = df_test[target].values
        y_proba_lr = pred_lr["prediction_score"].values
        y_proba_dt = pred_dt["prediction_score"].values
        y_pred_dt = pred_dt["prediction_label"].values
        
        # Métricas
        ll_lr = log_loss(y_true, y_proba_lr)
        ll_dt = log_loss(y_true, y_proba_dt)
        f1_dt = f1_score(y_true, y_pred_dt)
 
        # 4. Log das métricas
        mlflow.log_metric("logloss_lr", ll_lr)
        mlflow.log_metric("logloss_dt", ll_dt)
        mlflow.log_metric("f1_dt", f1_dt)
        
        # 5. Seleção do modelo final
        # Critério: menor log loss; em caso de empate, escolha aquele com maior F1
        if ll_lr < ll_dt:
            best_model, best_name = lr, "lr"
        elif ll_dt < ll_lr:
            best_model, best_name = dt, "dt"
        else:
            # empataram em logloss → escolher dt se F1 maior, senão lr
            best_model, best_name = (dt, "dt") if f1_dt > 0 else (lr, "lr")
        
        mlflow.log_param("modelo_escolhido", best_name)
        
        return best_model

Treinamento()
# Out:
# [04/07/25 23:32:52] INFO     Loading data from base_train (ParquetDataset)...                   ]8;id=933542;file://C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=670290;file://C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
#                     INFO     Loading data from base_test (ParquetDataset)...                    ]8;id=843326;file://C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=614839;file://C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pandas.io.formats.style.Styler object at 0x00000202C25B13D0>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pandas.io.formats.style.Styler object at 0x00000202C8F655D0>
# <IPython.core.display.HTML object>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pandas.io.formats.style.Styler object at 0x00000202C86C6590>
# <IPython.core.display.HTML object>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pandas.io.formats.style.Styler object at 0x00000202C8803110>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pandas.io.formats.style.Styler object at 0x00000202C90DBA10>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              lat         lon  minutes_remaining  period  playoffs  \
# 24157  33.888302 -118.382797                 11       3         1
# 441    34.021301 -118.159798                  2       3         0
# 20143  33.983299 -118.120796                 10       2         0
# 12366  34.044300 -118.269798                  0       4         0
# 7527   34.044300 -118.269798                  0       1         0
# ...          ...         ...                ...     ...       ...
# 275    34.031300 -118.298798                 11       2         0
# 882    34.042301 -118.184799                  6       1         0
# 18167  34.044300 -118.269798                  3       4         0
# 11830  33.934299 -118.377800                  5       1         0
# 18785  33.850300 -118.281799                  0       1         0
#
#        shot_distance  shot_made_flag  prediction_label  prediction_score
# 24157             19             0.0                 1            1.0000
# 441               11             0.0                 0            1.0000
# 20143             16             0.0                 0            1.0000
# 12366              0             1.0                 1            0.6140
# 7527               0             0.0                 1            0.5862
# ...              ...             ...               ...               ...
# 275                3             0.0                 0            1.0000
# 882                8             0.0                 0            1.0000
# 18167              0             1.0                 1            0.6047
# 11830             15             1.0                 0            1.0000
# 18785             19             0.0                 0            1.0000
#
# [4057 rows x 9 columns]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print("teste")
# Out:
# teste

# %%
# !conda activate kobe_pycaret

# %%
# !pip install scikit-learn==1.0.2
# Out:
# Collecting scikit-learn==1.0.2
#   Downloading scikit-learn-1.0.2.tar.gz (6.7 MB)
#      ---------------------------------------- 0.0/6.7 MB ? eta -:--:--
#      --- ------------------------------------ 0.5/6.7 MB 4.2 MB/s eta 0:00:02
#      --------- ------------------------------ 1.6/6.7 MB 5.2 MB/s eta 0:00:01
#      ------------------ --------------------- 3.1/6.7 MB 5.9 MB/s eta 0:00:01
#      ------------------------ --------------- 4.2/6.7 MB 6.0 MB/s eta 0:00:01
#      ------------------------ --------------- 4.2/6.7 MB 6.0 MB/s eta 0:00:01
#      ------------------------------- -------- 5.2/6.7 MB 4.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 6.0/6.7 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 6.7/6.7 MB 4.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [66 lines of output]
#   Partial import of sklearn during the build process.
#   setup.py:128: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.command.build_ext import build_ext  # noqa
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   Traceback (most recent call last):
#     File "C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#     File "C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 175, in prepare_metadata_for_build_wheel
#       return hook(metadata_directory, config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\build_meta.py", line 174, in prepare_metadata_for_build_wheel
#       self.run_setup()
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\build_meta.py", line 268, in run_setup
#       self).run_setup(setup_script=setup_script)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\build_meta.py", line 158, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 319, in <module>
#       setup_package()
#     File "setup.py", line 315, in setup_package
#       setup(**metadata)
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\numpy\distutils\core.py", line 135, in setup
#       config = configuration()
#                ^^^^^^^^^^^^^^^
#     File "setup.py", line 201, in configuration
#       config.add_subpackage("sklearn")
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 1050, in add_subpackage
#       config_list = self.get_subpackage(subpackage_name, subpackage_path,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 1016, in get_subpackage
#       config = self._get_configuration_from_setup_py(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\numpy\distutils\misc_util.py", line 958, in _get_configuration_from_setup_py
#       config = setup_module.configuration(*args)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-install-o4tu02kd\scikit-learn_a8b48a115c7446b0bef14599288876f7\sklearn\setup.py", line 85, in configuration
#       cythonize_extensions(top_path, config)
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-install-o4tu02kd\scikit-learn_a8b48a115c7446b0bef14599288876f7\sklearn\_build_utils\__init__.py", line 47, in cythonize_extensions
#       basic_check_build()
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-install-o4tu02kd\scikit-learn_a8b48a115c7446b0bef14599288876f7\sklearn\_build_utils\pre_build_helpers.py", line 114, in basic_check_build
#       compile_test_program(code)
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-install-o4tu02kd\scikit-learn_a8b48a115c7446b0bef14599288876f7\sklearn\_build_utils\pre_build_helpers.py", line 70, in compile_test_program
#       ccompiler.compile(
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 327, in compile
#       self.initialize()
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 224, in initialize
#       vc_env = _get_vc_env(plat_spec)
#                ^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\msvc.py", line 316, in msvc14_get_vc_env
#       return _msvc14_get_vc_env(plat_spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\paulo.rogerio\AppData\Local\Temp\pip-build-env-6iltz8mg\overlay\Lib\site-packages\setuptools\msvc.py", line 270, in _msvc14_get_vc_env
#       raise distutils.errors.DistutilsPlatformError(
#   distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install scikit-learn==1.1.3
# Out:
# Collecting scikit-learn==1.1.3
#   Downloading scikit_learn-1.1.3-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from scikit-learn==1.1.3) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from scikit-learn==1.1.3) (1.11.4)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from scikit-learn==1.1.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from scikit-learn==1.1.3) (3.6.0)
# Downloading scikit_learn-1.1.3-cp311-cp311-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.5 MB 6.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.5 MB 6.5 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.5 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.5 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 3.4/7.5 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.5 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed scikit-learn-1.1.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.1.3 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.1.3 which is incompatible.
# pycaret 3.3.0 requires scikit-learn>1.4.0, but you have scikit-learn 1.1.3 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.1.3 which is incompatible.

# %%
# !pip install --upgrade pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (8.35.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.61.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (8.6.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from sktime==0.26.0->pycaret) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.21.0)
# Requirement already satisfied: colorama in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipython>=5.5.0->pycaret) (4.13.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from numba>=0.55.0->pycaret) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from plotly>=5.14.0->pycaret) (9.1.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.0.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.16)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.12)
# Requirement already satisfied: urllib3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.3.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from pmdarima>=2.0.4->pycaret) (75.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from requests>=2.27.1->pycaret) (2025.1.31)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.6)
# Requirement already satisfied: retrying in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (310)
# Requirement already satisfied: wcwidth in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\paulo.rogerio\appdata\local\anaconda3\envs\kobe_pycaret\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
