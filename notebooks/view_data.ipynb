# %%
data = catalog.load("dataset_kobe_dev")
cols = [
    "lat", "lon", "minutes_remaining", 
    "period", "playoffs", "shot_distance", 
    "shot_made_flag"
]
display(data[cols].head())
print(data['shot_made_flag'].value_counts(normalize=True))
# Out:
# [04/10/25 22:40:52] INFO     Loading data from dataset_kobe_dev (ParquetDataset)...             ]8;id=130195;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=564488;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# shot_made_flag
# 0.0    0.522652
# 1.0    0.477348
# Name: proportion, dtype: float64

# %%
data = catalog.load("dataset_kobe_prod")
display(data)
print(data['shot_made_flag'].value_counts(normalize=True))
# Out:
# [04/12/25 10:59:47] INFO     Loading data from dataset_kobe_prod (ParquetDataset)...            ]8;id=216239;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=126630;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       action_type combined_shot_type  game_event_id   game_id      lat  loc_x  \
# 10      Jump Shot          Jump Shot            309  20000012  33.8063    -94
# 17      Jump Shot          Jump Shot            138  20000019  33.8183   -117
# 27      Jump Shot          Jump Shot            369  20000019  33.8583   -183
# 39      Jump Shot          Jump Shot            202  20000047  33.7723    -27
# ...

# %%
data = catalog.load("data_filtered")
data.describe()
# Out:
# [04/10/25 21:44:08] INFO     Loading data from data_filtered (ParquetDataset)...                ]8;id=758732;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=465814;file://c:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\kobe_pycaret\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        minutes_remaining        period      playoffs  shot_distance  \
# count       20285.000000  20285.000000  20285.000000   20285.000000
# mean            5.100173      2.471974      0.148731      10.216317
# std             3.423866      1.148192      0.355831       7.559547
# min             0.000000      1.000000      0.000000       0.000000
# 25%             2.000000      1.000000      0.000000       1.000000
# ...
